# %%
import pandas as pd
import plotly.express as px

# %%
df_progression = pd.read_csv("/workspaces/K-Means/data/progression.csv")
df_progression.sample(5)
# Out:
#     language version  threads  total_time_sec  throughput_exec_per_sec  \
# 151     java      v7        2        318.8900                 0.009408
# 22        go      v3        3         84.8105                 0.040000
# 205     java     v12        6        385.6850                 0.054449
# 112     java      v3        3        489.9950                 0.012245
# 174     java      v9        5        759.8400                 0.019741
#
#      avg_latency_ms
# 151     154484.0000
# 22       28270.1818
# 205      64309.4000
# 112     157239.0000
# 174     145318.0000

# %%
df_progression["lang_version"] = df_progression["language"] + "-" + df_progression["version"]

metrics = [
    "total_time_sec",
    "throughput_exec_per_sec",
    "avg_latency_ms"
]

for metric in metrics:
    fig = px.line(
        df_progression,
        x="threads",
        y=metric,
        color="lang_version",
        markers=True,
        title=f"Threads vs {metric}",
    )

    fig.update_layout(
        xaxis_title="Número de Threads",
        yaxis_title=metric,
        template="plotly_dark",
        hovermode="x unified"
    )

    fig.show()
